# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **pandas** : It used for data manipulation and analysis.
#
# **numPy** : It is a powerful Python library for numerical computing.
#
# **seaborn** :  It provides a high-level interface for creating attractive and informative statistical graphics.
#
# **matplotlib.pyplot** : It provides a MATLAB-like interface for creating basic plots and visualizations.

# %%
df=pd.read_csv("greenhouse-gas-emissions-by-region-industry-and-household.csv")

# %% [markdown]
# **pd.read_csv** is used to read the data from the csv files
#
# df is the variable in which the data is getting stored from the csv files

# %%
df
# Out:
#           region                                  anzsic_descriptor  \
# 0       Auckland  Forestry and logging, fishing, and agricultura...
# 1       Auckland  Forestry and logging, fishing, and agricultura...
# 2       Auckland  Forestry and logging, fishing, and agricultura...
# 3       Auckland  Forestry and logging, fishing, and agricultura...
# 4       Auckland  Forestry and logging, fishing, and agricultura...
# ...          ...                                                ...
# 1710  West Coast                                              Total
# 1711  West Coast                                              Total
# 1712  West Coast                                              Total
# 1713  West Coast                                              Total
# 1714  West Coast                                              Total
#
#      anzsic_descriptor2 category                         gas       units  \
# 0                 Total    Total  Carbon dioxide equivalents  Kilotonnes
# ...

# %%
df.head()
# Out:
#      region                                  anzsic_descriptor  \
# 0  Auckland  Forestry and logging, fishing, and agricultura...
# 1  Auckland  Forestry and logging, fishing, and agricultura...
# 2  Auckland  Forestry and logging, fishing, and agricultura...
# 3  Auckland  Forestry and logging, fishing, and agricultura...
# 4  Auckland  Forestry and logging, fishing, and agricultura...
#
#   anzsic_descriptor2 category                         gas       units  \
# 0              Total    Total  Carbon dioxide equivalents  Kilotonnes
# 1              Total    Total  Carbon dioxide equivalents  Kilotonnes
# 2              Total    Total  Carbon dioxide equivalents  Kilotonnes
# 3              Total    Total  Carbon dioxide equivalents  Kilotonnes
# 4              Total    Total  Carbon dioxide equivalents  Kilotonnes
#
#                     magnitude  year  data_val
# 0  Carbon dioxide equivalents  2007     39.43
# 1  Carbon dioxide equivalents  2008     40.36
# ...

# %% [markdown]
# **head()** --> function is used to read the starting 5 lines from the dataset

# %%
df.tail()
# Out:
#           region anzsic_descriptor anzsic_descriptor2 category  \
# 1710  West Coast             Total              Total    Total
# 1711  West Coast             Total              Total    Total
# 1712  West Coast             Total              Total    Total
# 1713  West Coast             Total              Total    Total
# 1714  West Coast             Total              Total    Total
#
#                              gas       units                   magnitude  \
# 1710  Carbon dioxide equivalents  Kilotonnes  Carbon dioxide equivalents
# 1711              Carbon dioxide  Kilotonnes  Carbon dioxide equivalents
# 1712                     Methane  Kilotonnes  Carbon dioxide equivalents
# 1713               Nitrous oxide  Kilotonnes  Carbon dioxide equivalents
# 1714           Fluorinated gases  Kilotonnes  Carbon dioxide equivalents
#
#       year  data_val
# 1710  2021   1107.60
# 1711  2021    464.88
# 1712  2021    476.68
# 1713  2021    148.93
# 1714  2021     17.11

# %% [markdown]
# **tail()** --> tail() function is used to read the ending 5 lines from the dataset

# %%
df.sample(8)
# Out:
#            region                   anzsic_descriptor anzsic_descriptor2  \
# 945   Marlborough                              Mining              Total
# 248    Canterbury                         Agriculture              Total
# 521   Marlborough  Agriculture, forestry, and fishing              Total
# 1554      Waikato                               Total              Total
# 810    West Coast                              Mining              Total
# 1131        Otago                               Total              Total
# 511   Marlborough  Agriculture, forestry, and fishing              Total
# 274   Hawke's Bay                         Agriculture              Total
#
#      category                         gas       units  \
# 945     Total  Carbon dioxide equivalents  Kilotonnes
# 248     Total  Carbon dioxide equivalents  Kilotonnes
# 521     Total  Carbon dioxide equivalents  Kilotonnes
# 1554    Total           Fluorinated gases  Kilotonnes
# ...

# %% [markdown]
# **sample(8)** --> function is used to get the sample of 8 rows from the given dataset

# %%
df.dtypes
# Out:
# region                 object
# anzsic_descriptor      object
# anzsic_descriptor2     object
# category               object
# gas                    object
# units                  object
# magnitude              object
# year                    int64
# data_val              float64
# dtype: object

# %% [markdown]
# **dtypes** --> It is used to get the datatype of the specified columns from the given datasets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   region              1714 non-null   object
#  1   anzsic_descriptor   1688 non-null   object
#  2   anzsic_descriptor2  1610 non-null   object
#  3   category            1536 non-null   object
#  4   gas                 1715 non-null   object
#  5   units               1605 non-null   object
#  6   magnitude           1715 non-null   object
#  7   year                1715 non-null   int64
#  8   data_val            1715 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 120.7+ KB

# %% [markdown]
# **info()** --> It is used to get the Information of about each and every columns
#
# It will also tell about the no. of the cells which are  non-empty by displaying their number

# %%
df.count()
# Out:
# region                1714
# anzsic_descriptor     1688
# anzsic_descriptor2    1610
# category              1536
# gas                   1715
# units                 1605
# magnitude             1715
# year                  1715
# data_val              1715
# dtype: int64

# %% [markdown]
# **count()** --> It is used to count the non-empty cells of each column
#
# It will display the number of that sooo...

# %%
df.shape
# Out:
# (1715, 9)

# %% [markdown]
# **shape** --> It is used to determine the dimensions or the size of an array or DataFrame.
#
# **1715 --> Rows**
#
# **9 --> Columns**

# %%
df.columns
# Out:
# Index(['region', 'anzsic_descriptor', 'anzsic_descriptor2', 'category', 'gas',
#        'units', 'magnitude', 'year', 'data_val'],
#       dtype='object')

# %% [markdown]
# **columns** --> It will display the column names

# %%
df['data_val'].mean()
# Out:
# 1611.6855918367346

# %% [markdown]
# **mean()** --> It is used to find the mean of the required column data

# %%
df['data_val'].median()
# Out:
# 570.6

# %% [markdown]
# **median()** --> It is used to find the median of the required column data

# %%
df['data_val'].std()
# Out:
# 2403.176448555146

# %% [markdown]
# **std()** --> It is used to find the Standard Deviation of the required column data

# %%
df['data_val'].mode()
# Out:
# 0    43.16
# 1    60.69
# Name: data_val, dtype: float64

# %% [markdown]
# **mode()** --> It is used to find the mode of the required column data

# %%
df.describe()
# Out:
#               year      data_val
# count  1715.000000   1715.000000
# mean   2013.948688   1611.685592
# std       4.237652   2403.176449
# min    2007.000000      0.860000
# 25%    2010.000000     63.550000
# 50%    2014.000000    570.600000
# 75%    2018.000000   2199.870000
# max    2021.000000  16948.820000

# %% [markdown]
# **describe()** --> It is used to describe the dataset into the count,mean,std,min,25%,50%(median),75%,max
#
# It will only describe and find the values of the dataset columns which are in float or integer

# %%
df["region"].value_counts()
# Out:
# Otago                 133
# Marlborough           133
# Southland             133
# Taranaki              133
# Northland             132
# West Coast            127
# Tasman/Nelson         118
# Wellington            118
# Waikato               118
# Manawatu-Whanganui    115
# Nelson                 75
# Tasman                 75
# Auckland               72
# Bay of Plenty          58
# Hawke's Bay            58
# Gisborne               58
# Canterbury             58
# Name: region, dtype: int64

# %% [markdown]
# **value_counts()** --> It will count the no. of times the specfic column name present in the dataset

# %%
df["gas"].unique() #list of unique entries
# Out:
# array(['Carbon dioxide equivalents', 'Nitrous oxide', 'Fluorinated gases',
#        'Carbon dioxide', 'Methane'], dtype=object)

# %% [markdown]
# **.unique()** --> It is used to count the unique enteries in that column

# %%
df.sort_values(["year"])
# Out:
#              region                                  anzsic_descriptor  \
# 0          Auckland  Forestry and logging, fishing, and agricultura...
# 322           Otago                                        Agriculture
# 336       Southland                                        Agriculture
# 350        Taranaki                                        Agriculture
# 364   Tasman/Nelson                                        Agriculture
# ...             ...                                                ...
# 1338       Taranaki                                              Total
# 1339       Taranaki                                              Total
# 964     Marlborough  Services excluding transport, postal, and ware...
# 539       Northland                 Agriculture, forestry, and fishing
# 1714     West Coast                                              Total
#
#      anzsic_descriptor2 category                         gas       units  \
# ...

# %% [markdown]
# **.sort_values()** --> It will sort the values and provides u the data in the sorting manner
#
# If ascending of descending is not given then by default it will give u the data in the ascending manner/order only

# %%
df.isnull().sum()
# Out:
# region                  1
# anzsic_descriptor      27
# anzsic_descriptor2    105
# category              179
# gas                     0
# units                 110
# magnitude               0
# year                    0
# data_val                0
# dtype: int64

# %% [markdown]
# **isnull()** --> It will Return u the no. of the empty cells in the row

# %%
df.drop(["anzsic_descriptor2","category","units"],axis=1,inplace=True)

# %% [markdown]
# **.drop()** --> It is used to delete the specified columns
#
# As the no. of the empty cells in the column anzsic_descriptor2 is 105
# and category is 179 and this both the columns are not useful to predict the data so deleting both the columns

# %%
df.head()
# Out:
#      region                                  anzsic_descriptor  \
# 0  Auckland  Forestry and logging, fishing, and agricultura...
# 1  Auckland  Forestry and logging, fishing, and agricultura...
# 2  Auckland  Forestry and logging, fishing, and agricultura...
# 3  Auckland  Forestry and logging, fishing, and agricultura...
# 4  Auckland  Forestry and logging, fishing, and agricultura...
#
#                           gas                   magnitude  year  data_val
# 0  Carbon dioxide equivalents  Carbon dioxide equivalents  2007     39.43
# 1  Carbon dioxide equivalents  Carbon dioxide equivalents  2008     40.36
# 2  Carbon dioxide equivalents  Carbon dioxide equivalents  2009     30.18
# 3  Carbon dioxide equivalents  Carbon dioxide equivalents  2010     25.66
# 4  Carbon dioxide equivalents  Carbon dioxide equivalents  2011     42.59

# %% [markdown]
# Checking for the deleted columns

# %%
df.dropna(inplace=True)

# %% [markdown]
# **dropna()** --> It is used to delete the rows which have very less null values
# and then bring the data in the equal manner.

# %%
df.isnull().sum()
# Out:
# region               0
# anzsic_descriptor    0
# gas                  0
# magnitude            0
# year                 0
# data_val             0
# dtype: int64

# %% [markdown]
# There is no null cell in the rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1687 entries, 0 to 1714
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             1687 non-null   object
#  1   anzsic_descriptor  1687 non-null   object
#  2   gas                1687 non-null   object
#  3   magnitude          1687 non-null   object
#  4   year               1687 non-null   int64
#  5   data_val           1687 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 92.3+ KB

# %% [markdown]
# ***DETECTING OUTLIER***
#
# **Outlier** --> It is an extreme value that falls far outside the typical range of values in a dataset.
#
# It is a **Univarient Analysis**
#
# Bcz we are analyzing using the single variable

# %%
sns.boxplot(x=df['year'])
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# There is no outlier in the year column

# %%
sns.boxplot(x=df['data_val'])
# Out:
# <Axes: xlabel='data_val'>

# %% [markdown]
# There are outlier in the data_val column

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# year           8.00
# data_val    2119.57
# dtype: float64
# <ipython-input-30-d7397e803310>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# <ipython-input-30-d7397e803310>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %% [markdown]
# This **Calculates Interquartile Range (IQR)** for each column in 25 % and 75 %
# and then it will substract to get the 50% of Interquartile Range (IQR)

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# <ipython-input-31-f4e1682787c4>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# (1542, 6)

# %% [markdown]
# **(df < (Q1 - 1.5 * IQR))**: This part of the expression checks if any value in the DataFrame is **less** than the **lower bound** (Q1 - 1.5 * IQR).
#
# **(df > (Q3 + 1.5 * IQR))**: This part of the expression checks if any value in the DataFrame is **greater** than the **upper bound** (Q3 + 1.5 * IQR).
#
# The **|** operator is used to combine these two conditions with an **OR** operation.

# %%
sns.boxplot(x=df['data_val'])
# Out:
# <Axes: xlabel='data_val'>

# %% [markdown]
# **Outliers are removed sucessfully**

# %% [markdown]
# **EDA (Exploratory Data Analysis)**
#
# It is used to understand the main characteristics, patterns, and insights hidden in the data.

# %%
plt.scatter(df['year'],df['data_val'])

# %% [markdown]
# ***Scatter PlotT***
#
# It is Bivarent analysis because the 2 variables that is x and y are used.
#
#  It represents data points as individual dots on a two-dimensional plane, with one variable on the x-axis and the other variable on the y-axis. Each dot represents an observation or data point.
#
#  In this also year is the x axis whereas the data_val is the y axis

# %%
pie=df['region'].value_counts()
pie
# Out:
# Otago                 133
# Marlborough           133
# West Coast            127
# Taranaki              119
# Wellington            118
# Tasman/Nelson         118
# Southland             118
# Manawatu-Whanganui    104
# Northland             103
# Nelson                 75
# Tasman                 75
# Auckland               72
# Bay of Plenty          58
# Hawke's Bay            58
# Gisborne               58
# Waikato                44
# Canterbury             29
# Name: region, dtype: int64

# %%
pie.plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='region'>

# %%
df["gas"].value_counts().plot(kind="pie",autopct="%.4f%%")
# Out:
# <Axes: ylabel='gas'>

# %% [markdown]
# **Pie Chart**
#
# It is univarient analysis , as single variable is used.
#
# In this region and gas can show the region in the pie format.
#
# It is called a **"pie chart"** because the chart resembles a pie that is divided into slices, with each slice representing a **particular category or data point.** The size of each slice corresponds to the **proportion or percentage** of the whole that each category represents.

# %%
sns.catplot(x ='year', hue ='gas',kind ='count', data = df)

# %% [markdown]
# **Count Plot**
#
#
# In the Countplots height of each bar represents the number of occurrences of each category in the dataset. Countplots are particularly useful for visualizing the frequency of different categories and identifying the most common or least common categories in the data.
#
# In this the number of the gases released in each year.

# %%
sns.displot(df['data_val'],kde=True)

# %% [markdown]
# **DisPlot**
#
# displot is used to create a **histogram** to visualize the distribution of a numerical variable.
#
# It is used to create a **KDE** plot to visualize the estimated probability density function of a numerical variable. KDE plots show the **smoothed continuous representation** of the data distribution.

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="PuOr",annot=True)
c
# Out:
# <ipython-input-79-38bf0624e2ab>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#               year  data_val
# year      1.000000  0.001425
# data_val  0.001425  1.000000

# %% [markdown]
# **Heatmaps**
#
# The colors on a heatmap are used to represent the magnitude or density of the data points at different locations, with warmer colors  typically indicating higher values, and cooler colors indicating lower values.

# %% [markdown]
# **DATA PREPROCESSING**

# %% [markdown]
# In machine learning, splitting the data into X and Y components serves the purpose of preparing the data for model training and evaluation. The X and Y components represent the features (input) and the corresponding target variable (output) for the learning process. This separation is crucial for several reasons:
#
# 1. **Training the Model:** In supervised machine learning, we have a dataset with input-output pairs. The X-axis contains the input features (often denoted as X or features matrix), and the Y-axis contains the corresponding target values (often denoted as Y or target vector). During model training, the algorithm learns from the patterns in the input-output relationships to make predictions.
#
# 2. **Feature Extraction:** The X-axis includes the features or attributes that are used to describe the data instances. Each row in the X-axis represents an individual data point, and each column corresponds to a specific feature. Feature extraction and selection are essential steps in machine learning, and separating features from the target variable allows you to apply different preprocessing steps to them independently.
#
# 3. **Model Evaluation:** After training a machine learning model, it needs to be evaluated to assess its performance and generalization ability on unseen data. For evaluation, the model is provided with new input features (X) to make predictions, and the predictions are compared with the corresponding target values (Y) to calculate performance metrics like accuracy, mean squared error, etc.
#
# 4. **Avoiding Data Leakage:** Data leakage is a situation where information from the target variable is inadvertently included in the features during model training. This can lead to overfitting, where the model performs well on the training data but poorly on new, unseen data. By keeping the target variable (Y) separate from the features (X) during training, we prevent data leakage and ensure the model's ability to generalize to new data.
#
# 5. **Cross-Validation:** When performing cross-validation, where the dataset is split into multiple subsets for training and testing, keeping X and Y separate is essential. This helps ensure that during each fold of cross-validation, the model doesn't get access to the target variable of the test set, preventing any data leakage.

# %%
x=df.iloc[:,0:5]
x
# Out:
#           region                                  anzsic_descriptor  \
# 0       Auckland  Forestry and logging, fishing, and agricultura...
# 1       Auckland  Forestry and logging, fishing, and agricultura...
# 2       Auckland  Forestry and logging, fishing, and agricultura...
# 3       Auckland  Forestry and logging, fishing, and agricultura...
# 4       Auckland  Forestry and logging, fishing, and agricultura...
# ...          ...                                                ...
# 1710  West Coast                                              Total
# 1711  West Coast                                              Total
# 1712  West Coast                                              Total
# 1713  West Coast                                              Total
# 1714  West Coast                                              Total
#
#                              gas                   magnitude  year
# 0     Carbon dioxide equivalents  Carbon dioxide equivalents  2007
# ...

# %% [markdown]
# **In x axis we r including all the columns except the targeted row which will be the y axis**

# %%
y=df.iloc[:,5]
y
# Out:
# 0         39.43
# 1         40.36
# 2         30.18
# 3         25.66
# 4         42.59
#          ...
# 1710    1107.60
# 1711     464.88
# 1712     476.68
# 1713     148.93
# 1714      17.11
# Name: data_val, Length: 1542, dtype: float64

# %% [markdown]
# **In y axis we r including the targeted row only i.e data_val row**
#
# **Which will going to calculate and give us the value of the data i.e how much greenhouse gass emmision would be produced by each region in the year**

# %% [markdown]
# **ENCODING**
#
# In Encoding we will convert all the **object** datatype of the column to the integer for the Machine Learning Process

# %%
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# **OriginalEncoder** --> It is usedfor encoding categorical features into ordinal integers

# %%
oe=OrdinalEncoder()
x[["region","anzsic_descriptor","gas","magnitude"]]=oe.fit_transform(x[["region","anzsic_descriptor","gas","magnitude"]])
x
# Out:
#       region  anzsic_descriptor  gas  magnitude  year
# 0        0.0                2.0  1.0        0.0  2007
# 1        0.0                2.0  1.0        0.0  2008
# 2        0.0                2.0  1.0        0.0  2009
# 3        0.0                2.0  1.0        0.0  2010
# 4        0.0                2.0  1.0        0.0  2011
# ...      ...                ...  ...        ...   ...
# 1710    16.0                9.0  1.0        0.0  2021
# 1711    16.0                9.0  0.0        0.0  2021
# 1712    16.0                9.0  3.0        0.0  2021
# 1713    16.0                9.0  4.0        0.0  2021
# 1714    16.0                9.0  2.0        0.0  2021
#
# [1542 rows x 5 columns]

# %% [markdown]
# **Fit** : to perform calculations on data
#
# **Transform** : apply that calculation
#
# Converting the Object data type of columns to the integer using fit_transform with OriginalEncoder of X-axis

# %% [markdown]
# **MODEL**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **train_test_split**  --> It is used to split a dataset into two (or more) subsets

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# x and y axis is splitted into xtrain , xtest , ytrain ,ytest
#
# where xtrain and xtest will give the output model then the ytrain is provided to the model which gives the predicted value of y predy
#
# which is further compared with the ytest to be accurate

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# **LogisticRegression** --> It is used to perform logistic regression
#
# **classification_report** --> It provides a comprehensive report with metrics such as precision, recall, F1-score, and support for both classes (positive and negative). It helps you understand the performance of the model for each class and overall accuracy.
#
# **confusion_matrix** --> It provides a matrix that compares the predicted class labels against the actual class labels. It helps to visualize the number of true positives, false positives, true negatives, and false negatives, which is useful for understanding the model's performance and identifying potential areas for improvement.

# %%
#step1 -: import the model
from sklearn.linear_model import LinearRegression

#step2 -: initalize the model
linreg = LinearRegression()

#step3 -: train the model -> m & c
linreg.fit(xtrain, ytrain)

#step4 -: make prediction
ypred = linreg.predict(xtest)

# %% [markdown]
# **step1** -: import the model
#
#
# **step2** -: initalize the model
#
#
# **step3** -: train the model -> m & c
#
#
# **step4**-: make prediction

# %%
from sklearn.metrics import r2_score
print(f"Accuracy : {r2_score(ytest, ypred)}")
# Out:
# Accuracy : 0.0380769180265933

# %% [markdown]
# **Accuracy** : It is used to see how much accurate the data it is providing by comparing the ypred and ytest

# %%
linreg.intercept_
# Out:
# -12511.346844205887

# %% [markdown]
# **linreg.intercept_** : It provides the value of the intercept

# %%
linreg.coef_
# Out:
# array([ 15.57394072, -55.13586719, -89.9893475 ,   0.        ,
#          6.85980886])

# %% [markdown]
# **linreg.coef_** : It represents the coefficients (or weights) associated with each input feature in the linear regression equation.

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x,y)
ypred=model.predict(x)

# %% [markdown]
# object of linear regression class
#
# training of model
#
# testing of model
#
# ypred stores the predicted value of y store hai

# %%
ypred
# Out:
# array([1084.9060869 , 1088.34505738, 1091.78402786, ...,  761.2981956 ,
#         651.52587902,  871.07051217])

# %%
from sklearn.metrics import r2_score
r2_score(y,ypred)
# Out:
# 0.03444238711537173

# %%
model.intercept_
# Out:
# -5600.714525932981

# %%
model.coef_
# Out:
# array([  13.81025172,  -53.31041034, -109.77231657,    0.        ,
#           3.43897048])

# %%
x
# Out:
#       region  anzsic_descriptor  gas  magnitude  year
# 0        0.0                2.0  1.0        0.0  2007
# 1        0.0                2.0  1.0        0.0  2008
# 2        0.0                2.0  1.0        0.0  2009
# 3        0.0                2.0  1.0        0.0  2010
# 4        0.0                2.0  1.0        0.0  2011
# ...      ...                ...  ...        ...   ...
# 1710    16.0                9.0  1.0        0.0  2021
# 1711    16.0                9.0  0.0        0.0  2021
# 1712    16.0                9.0  3.0        0.0  2021
# 1713    16.0                9.0  4.0        0.0  2021
# 1714    16.0                9.0  2.0        0.0  2021
#
# [1542 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_873307056365293381 = autoviz.get_df('df_873307056365293381')
#
# ...

# %%
r=int(input("\n 0. Auckland\t 1. Bay of Plenty\t 2. Canterbury\t 3. Gisborne\t 4. Hawke's Bay\t 5. Manawatu-Whanganui\t 8. Marlborough\t 9. Northland\t 10. Otago\t 11. Southland\t 13. Taranaki\t 14. Tasman/Nelson\t 15. Waikato\t 16. Wellington\n Enter the Region :  "))

a=int(input("\n0. Agriculture\t 1. Agriculture, forestry, and fishing\t 2. Forestry and logging, fishing, and agricultural support services\t 3. Goods-producing industries\t 4. Manufacturing\t 5. Mining\t 6. Primary industries\t 7. Service industries\t 8. Services excluding transport, postal, and warehousing\t 9. Total\n Enter the anzsic_descriptor : "))

g=int(input("\n 0. Carbon dioxide\t 1. Carbon dioxide equivalents\t 2. Fluorinated gases \t 3. Methane\t 4. Nitrous oxide\n Enter the Gas Released from the region : "))

m=0.0

year=int(input("\nEnter the Year : "))

unknown_y=[[r,a,g,m,year]]

ynew=model.predict(unknown_y)

print("\n\nThe Value of the greenhouse gas emissions by region industry and household is :  ",ynew)
# Out:
#  0. Auckland	 1. Bay of Plenty	 2. Canterbury	 3. Gisborne	 4. Hawke's Bay	 5. Manawatu-Whanganui	 8. Marlborough	 9. Northland	 10. Otago	 11. Southland	 13. Taranaki	 14. Tasman/Nelson	 15. Waikato	 16. Wellington
#  Enter the Region :  5
#
# 0. Agriculture	 1. Agriculture, forestry, and fishing	 2. Forestry and logging, fishing, and agricultural support services	 3. Goods-producing industries	 4. Manufacturing	 5. Mining	 6. Primary industries	 7. Service industries	 8. Services excluding transport, postal, and warehousing	 9. Total
#  Enter the anzsic_descriptor : 4
#
#  0. Carbon dioxide	 1. Carbon dioxide equivalents	 2. Fluorinated gases 	 3. Methane	 4. Nitrous oxide
#  Enter the Gas Released from the region : 0
#
# Enter the Year : 2018
#
#
# The Value of the greenhouse gas emissions by region industry and household is :   [1194.93751666]
# ...

# %% [markdown]
# In this We are taking the input from the user i.e region, anzsic_descriptor,	gas,	magnitude, year
#
# And after taking input we are Predicting the value of the greenhouse gas emissions by region industry and household

# %% [markdown]
# **SUMMARY**

# %% [markdown]
# From this Dataset of greenhouse-gas-emissions-by-region-industry-and-household
#
# We have found the gas emmisions releases from each region
#
# Each and Every Region releases different types of the gases
#
# By Providing the Year the value of greenhouse gas emissions by region industry and household can be predicted
